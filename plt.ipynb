# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from time import sleep
import gc

# %%
iris = pd.read_csv("./result/iris/05-29-04-50_50_500_0.5_0.8_0.7_acc.csv", header=None)
print(iris.shape)
# print(iris.head)
loss = []
acc = []
for i in range(len(iris.iloc[0])):
    if i % 2 == 0:
        loss.append(iris[i])
    else:
        acc.append(iris[i])

plt.subplot(2,1,1)
plt.grid()
plt.ylabel("loss")
plt.title(f"loss and acc")
for i in range(len(loss)):
    plt.plot(loss[i], label=f"loss_{i}")

plt.subplot(2,1,2)
plt.grid()
plt.xlabel("epoch")

plt.ylabel("acc")
for i in range(len(acc)):
    plt.plot(acc[i], label=f"acc_{i}")

plt.show()
plt.clf()
plt.clf()
plt.close()

gc.collect()
# Out:
# (15, 100)
# 15093
