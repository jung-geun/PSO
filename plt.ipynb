# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from time import sleep
import gc

# %%
iris = pd.read_csv("./result/mnist/06-23-06-43_50_200_0.35_0.8_0.7_acc.csv", header=None)
print(iris.shape)

loss = []
acc = []

for i in range(len(iris.iloc[0])):
    if i % 2 == 0:
        loss.append(iris[i])
    else:
        acc.append(iris[i])

plt.subplot(2,1,1)
plt.grid()
plt.ylabel("loss")
plt.title(f"loss and acc")
for i in range(len(loss)):
    try:
        plt.plot(loss[i], label=i)
    except Exception as e:
        print(e)
        
plt.subplot(2,1,2)
plt.grid()
plt.xlabel("epoch")
plt.ylabel("acc")
for i in range(len(acc)):
    plt.plot(acc[i], label=i)

plt.show()
plt.clf()
plt.clf()
plt.close()
# Out:
# (33, 100)
